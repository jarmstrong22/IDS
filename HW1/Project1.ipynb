# %% [markdown]
# Jaden Armstrong
# 09/06/23
# Project1
# CSC346
# =========================================
# Problem 1:
# *Graph can be found below, titled Sum of Weight by Feed
# Analysis: The above results repreent the related weights of groups of chicken based on the primary food type fed to them. Different metrics that were tracked include minimum weight, maximum weight, and average weight. The goal of the research is to find the optimal food source for growing chicken, based on the research this would be Sunflower. Sunflower leads in each category; the highest minimum, average, and maximum weight. Close behind, also a viable option, is Casein which is second in every tracked category. A farmer who is attempting to maximize production and promote a thriving poultry business should choose Sunflower based on the previously listed reasons from the results.
#
# Problem 2:
# *Graoh can be found below, titled Ratings (out of 10) of Insurance Providers
# Analysis: The graph represents the minimun, maximum, and average of three ratings each given by customers to insurance providers. Contrary to the last analysis, the verdict is not difinitive since one insurance provider is not leading in every category. Although judging by the ratings, USAA is a clear last place. Both GIECO and Progressive are similar in that they both lead in maximum rating and average rating, respectively. If I were to choose one, I would pick Progressive since the average rating is higher than the rest. Although GIECO may also be the best option since it is possible its minimum rating (4.7) may be an outlier with a growing sample size. But with the data that is available to us, Progressive seems to be the best option

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
